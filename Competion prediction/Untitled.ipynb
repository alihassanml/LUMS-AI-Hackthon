# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Flatten
from tensorflow.keras.utils import to_categorical
import warnings
warnings.filterwarnings('ignore')
# Out:
# 2024-12-29 14:31:27.957882: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1735464687.990866 1210674 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1735464687.996543 1210674 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-29 14:31:28.021204: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from tensorflow.keras.models import load_model

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Bidirectional, Attention
from tensorflow.keras.layers import TimeDistributed

# %%
ls
# Out:
# 'Final Dataset'/   model_2.h5   prediction.ipynb   result_4.csv
#  gru_mode.csv      model_3.h5   result_1.csv       Untitled.ipynb
#  gru_mode.h5       model_4.h5   result_2.csv
#  model_1.h5        predict/     result_3.csv

# %%
NUM_CLASSES = 25
NUM_FRAMES = 100
INPUT_DIM = 2
DATA_DIR = "Final Dataset"

# %%
data_dir = "Final Dataset"
X = []
files = os.listdir(data_dir)
file = sorted(files)
for csv_file in files:
    file_path = os.path.join(data_dir, csv_file)
    data = pd.read_csv(file_path)
    if len(data) == NUM_FRAMES:  # Ensure the correct number of frames
        X.append(data[['x', 'y']].values)
# X = np.array(X, dtype=np.float32)

# %%
file
# Out:
# ['.~lock.1.csv#',
#  '1.csv',
#  '10.csv',
#  '100.csv',
#  '1000.csv',
#  '1001.csv',
#  '1002.csv',
#  '1003.csv',
#  '1004.csv',
#  '1005.csv',
#  '1006.csv',
#  '1007.csv',
#  '1008.csv',
#  '1009.csv',
#  '101.csv',
#  '1010.csv',
#  '1011.csv',
#  '1012.csv',
#  '1013.csv',
#  '1014.csv',
#  '1015.csv',
#  '1016.csv',
#  '1017.csv',
#  '1018.csv',
#  '1019.csv',
#  '102.csv',
#  '1020.csv',
#  '1021.csv',
#  '1022.csv',
#  '1023.csv',
#  '1024.csv',
#  '1025.csv',
#  '1026.csv',
#  '1027.csv',
#  '1028.csv',
#  '1029.csv',
#  '103.csv',
#  '1030.csv',
#  '1031.csv',
#  '1032.csv',
#  '1033.csv',
#  '1034.csv',
#  '1035.csv',
#  '1036.csv',
#  '1037.csv',
#  '1038.csv',
#  '1039.csv',
#  '104.csv',
#  '1040.csv',
#  '1041.csv',
#  '1042.csv',
#  '1043.csv',
#  '1044.csv',
#  '1045.csv',
#  '1046.csv',
#  '1047.csv',
#  '1048.csv',
#  '1049.csv',
#  '105.csv',
#  '1050.csv',
#  '1051.csv',
#  '1052.csv',
#  '1053.csv',
#  '1054.csv',
#  '1055.csv',
#  '1056.csv',
#  '1057.csv',
#  '1058.csv',
#  '1059.csv',
#  '106.csv',
#  '1060.csv',
#  '1061.csv',
#  '1062.csv',
#  '1063.csv',
#  '1064.csv',
#  '1065.csv',
#  '1066.csv',
#  '1067.csv',
#  '1068.csv',
#  '1069.csv',
#  '107.csv',
#  '1070.csv',
#  '1071.csv',
#  '1072.csv',
#  '1073.csv',
#  '1074.csv',
#  '1075.csv',
#  '1076.csv',
#  '1077.csv',
#  '1078.csv',
#  '1079.csv',
#  '108.csv',
#  '1080.csv',
#  '1081.csv',
#  '1082.csv',
#  '1083.csv',
#  '1084.csv',
#  '1085.csv',
#  '1086.csv',
#  '1087.csv',
#  '1088.csv',
#  '1089.csv',
#  '109.csv',
#  '1090.csv',
#  '1091.csv',
#  '1092.csv',
#  '1093.csv',
#  '1094.csv',
#  '1095.csv',
#  '1096.csv',
#  '1097.csv',
#  '1098.csv',
#  '1099.csv',
#  '11.csv',
#  '110.csv',
#  '1100.csv',
#  '1101.csv',
#  '1102.csv',
#  '1103.csv',
#  '1104.csv',
#  '1105.csv',
#  '1106.csv',
#  '1107.csv',
#  '1108.csv',
#  '1109.csv',
#  '111.csv',
#  '1110.csv',
#  '1111.csv',
#  '1112.csv',
#  '1113.csv',
#  '1114.csv',
#  '1115.csv',
#  '1116.csv',
#  '1117.csv',
#  '1118.csv',
#  '1119.csv',
#  '112.csv',
#  '1120.csv',
#  '1121.csv',
#  '1122.csv',
#  '1123.csv',
#  '1124.csv',
#  '1125.csv',
#  '1126.csv',
#  '1127.csv',
#  '1128.csv',
#  '1129.csv',
#  '113.csv',
#  '1130.csv',
#  '1131.csv',
#  '1132.csv',
#  '1133.csv',
#  '1134.csv',
#  '1135.csv',
#  '1136.csv',
#  '1137.csv',
#  '1138.csv',
#  '1139.csv',
#  '114.csv',
#  '1140.csv',
#  '1141.csv',
#  '1142.csv',
#  '1143.csv',
#  '1144.csv',
#  '1145.csv',
#  '1146.csv',
#  '1147.csv',
#  '1148.csv',
#  '1149.csv',
#  '115.csv',
#  '1150.csv',
#  '1151.csv',
#  '1152.csv',
#  '1153.csv',
#  '1154.csv',
#  '1155.csv',
#  '1156.csv',
#  '1157.csv',
#  '1158.csv',
#  '1159.csv',
#  '116.csv',
#  '1160.csv',
#  '1161.csv',
#  '1162.csv',
#  '1163.csv',
#  '1164.csv',
#  '1165.csv',
#  '1166.csv',
#  '1167.csv',
#  '1168.csv',
#  '1169.csv',
#  '117.csv',
#  '1170.csv',
#  '1171.csv',
#  '1172.csv',
#  '1173.csv',
#  '1174.csv',
#  '1175.csv',
#  '1176.csv',
#  '1177.csv',
#  '1178.csv',
#  '1179.csv',
#  '118.csv',
#  '1180.csv',
#  '1181.csv',
#  '1182.csv',
#  '1183.csv',
#  '1184.csv',
#  '1185.csv',
#  '1186.csv',
#  '1187.csv',
#  '1188.csv',
#  '1189.csv',
#  '119.csv',
#  '1190.csv',
#  '1191.csv',
#  '1192.csv',
#  '1193.csv',
#  '1194.csv',
#  '1195.csv',
#  '1196.csv',
#  '1197.csv',
#  '1198.csv',
#  '1199.csv',
#  '12.csv',
#  '120.csv',
#  '1200.csv',
#  '1201.csv',
#  '1202.csv',
#  '1203.csv',
#  '1204.csv',
#  '1205.csv',
#  '1206.csv',
#  '1207.csv',
#  '1208.csv',
#  '1209.csv',
#  '121.csv',
#  '1210.csv',
#  '1211.csv',
#  '1212.csv',
#  '1213.csv',
#  '1214.csv',
#  '1215.csv',
#  '1216.csv',
#  '1217.csv',
#  '1218.csv',
#  '1219.csv',
#  '122.csv',
#  '1220.csv',
#  '1221.csv',
#  '1222.csv',
#  '1223.csv',
#  '1224.csv',
#  '1225.csv',
#  '1226.csv',
#  '1227.csv',
#  '1228.csv',
#  '1229.csv',
#  '123.csv',
#  '1230.csv',
#  '1231.csv',
#  '1232.csv',
#  '1233.csv',
#  '1234.csv',
#  '1235.csv',
#  '1236.csv',
#  '1237.csv',
#  '1238.csv',
#  '1239.csv',
#  '124.csv',
#  '1240.csv',
#  '1241.csv',
#  '1242.csv',
#  '1243.csv',
#  '1244.csv',
#  '1245.csv',
#  '1246.csv',
#  '1247.csv',
#  '1248.csv',
#  '1249.csv',
#  '125.csv',
#  '1250.csv',
#  '1251.csv',
#  '1252.csv',
#  '1253.csv',
#  '1254.csv',
#  '1255.csv',
#  '1256.csv',
#  '1257.csv',
#  '1258.csv',
#  '1259.csv',
#  '126.csv',
#  '1260.csv',
#  '1261.csv',
#  '1262.csv',
#  '1263.csv',
#  '1264.csv',
#  '1265.csv',
#  '1266.csv',
#  '1267.csv',
#  '1268.csv',
#  '1269.csv',
#  '127.csv',
#  '1270.csv',
#  '1271.csv',
#  '1272.csv',
#  '1273.csv',
#  '1274.csv',
#  '1275.csv',
#  '1276.csv',
#  '1277.csv',
#  '1278.csv',
#  '1279.csv',
#  '128.csv',
#  '1280.csv',
#  '1281.csv',
#  '1282.csv',
#  '1283.csv',
#  '1284.csv',
#  '1285.csv',
#  '1286.csv',
#  '1287.csv',
#  '1288.csv',
#  '1289.csv',
#  '129.csv',
#  '1290.csv',
#  '1291.csv',
#  '1292.csv',
#  '1293.csv',
#  '1294.csv',
#  '1295.csv',
#  '1296.csv',
#  '1297.csv',
#  '1298.csv',
#  '1299.csv',
#  '13.csv',
#  '130.csv',
#  '1300.csv',
#  '1301.csv',
#  '1302.csv',
#  '1303.csv',
#  '1304.csv',
#  '1305.csv',
#  '1306.csv',
#  '1307.csv',
#  '1308.csv',
#  '1309.csv',
#  '131.csv',
#  '1310.csv',
#  '1311.csv',
#  '1312.csv',
#  '1313.csv',
#  '1314.csv',
#  '1315.csv',
#  '1316.csv',
#  '1317.csv',
#  '1318.csv',
#  '1319.csv',
#  '132.csv',
#  '1320.csv',
#  '1321.csv',
#  '1322.csv',
#  '1323.csv',
#  '1324.csv',
#  '1325.csv',
#  '1326.csv',
#  '1327.csv',
#  '1328.csv',
#  '1329.csv',
#  '133.csv',
#  '1330.csv',
#  '1331.csv',
#  '1332.csv',
#  '1333.csv',
#  '1334.csv',
#  '1335.csv',
#  '1336.csv',
#  '1337.csv',
#  '1338.csv',
#  '1339.csv',
#  '134.csv',
#  '1340.csv',
#  '1341.csv',
#  '1342.csv',
#  '1343.csv',
#  '1344.csv',
#  '1345.csv',
#  '1346.csv',
#  '1347.csv',
#  '1348.csv',
#  '1349.csv',
#  '135.csv',
#  '1350.csv',
#  '1351.csv',
#  '1352.csv',
#  '1353.csv',
#  '1354.csv',
#  '1355.csv',
#  '1356.csv',
#  '1357.csv',
#  '1358.csv',
#  '1359.csv',
#  '136.csv',
#  '1360.csv',
#  '1361.csv',
#  '1362.csv',
#  '1363.csv',
#  '1364.csv',
#  '1365.csv',
#  '1366.csv',
#  '1367.csv',
#  '1368.csv',
#  '1369.csv',
#  '137.csv',
#  '1370.csv',
#  '1371.csv',
#  '1372.csv',
#  '1373.csv',
#  '1374.csv',
#  '1375.csv',
#  '1376.csv',
#  '1377.csv',
#  '1378.csv',
#  '1379.csv',
#  '138.csv',
#  '1380.csv',
#  '1381.csv',
#  '1382.csv',
#  '1383.csv',
#  '1384.csv',
#  '1385.csv',
#  '1386.csv',
#  '1387.csv',
#  '1388.csv',
#  '1389.csv',
#  '139.csv',
#  '1390.csv',
#  '1391.csv',
#  '1392.csv',
#  '1393.csv',
#  '1394.csv',
#  '1395.csv',
#  '1396.csv',
#  '1397.csv',
#  '1398.csv',
#  '1399.csv',
#  '14.csv',
#  '140.csv',
#  '1400.csv',
#  '1401.csv',
#  '1402.csv',
#  '1403.csv',
#  '1404.csv',
#  '1405.csv',
#  '1406.csv',
#  '1407.csv',
#  '1408.csv',
#  '1409.csv',
#  '141.csv',
#  '1410.csv',
#  '1411.csv',
#  '1412.csv',
#  '1413.csv',
#  '1414.csv',
#  '1415.csv',
#  '1416.csv',
#  '1417.csv',
#  '1418.csv',
#  '1419.csv',
#  '142.csv',
#  '1420.csv',
#  '1421.csv',
#  '1422.csv',
#  '1423.csv',
#  '1424.csv',
#  '1425.csv',
#  '1426.csv',
#  '1427.csv',
#  '1428.csv',
#  '1429.csv',
#  '143.csv',
#  '1430.csv',
#  '1431.csv',
#  '1432.csv',
#  '1433.csv',
#  '1434.csv',
#  '1435.csv',
#  '1436.csv',
#  '1437.csv',
#  '1438.csv',
#  '1439.csv',
#  '144.csv',
#  '1440.csv',
#  '1441.csv',
#  '1442.csv',
#  '1443.csv',
#  '1444.csv',
#  '1445.csv',
#  '1446.csv',
#  '1447.csv',
#  '1448.csv',
#  '1449.csv',
#  '145.csv',
#  '1450.csv',
#  '1451.csv',
#  '1452.csv',
#  '1453.csv',
#  '1454.csv',
#  '1455.csv',
#  '1456.csv',
#  '1457.csv',
#  '1458.csv',
#  '1459.csv',
#  '146.csv',
#  '1460.csv',
#  '1461.csv',
#  '1462.csv',
#  '1463.csv',
#  '1464.csv',
#  '1465.csv',
#  '1466.csv',
#  '1467.csv',
#  '1468.csv',
#  '1469.csv',
#  '147.csv',
#  '1470.csv',
#  '1471.csv',
#  '1472.csv',
#  '1473.csv',
#  '1474.csv',
#  '1475.csv',
#  '1476.csv',
#  '1477.csv',
#  '1478.csv',
#  '1479.csv',
#  '148.csv',
#  '1480.csv',
#  '1481.csv',
#  '1482.csv',
#  '1483.csv',
#  '1484.csv',
#  '1485.csv',
#  '1486.csv',
#  '1487.csv',
#  '1488.csv',
#  '1489.csv',
#  '149.csv',
#  '1490.csv',
#  '1491.csv',
#  '1492.csv',
#  '1493.csv',
#  '1494.csv',
#  '1495.csv',
#  '1496.csv',
#  '1497.csv',
#  '1498.csv',
#  '1499.csv',
#  '15.csv',
#  '150.csv',
#  '1500.csv',
#  '1501.csv',
#  '1502.csv',
#  '1503.csv',
#  '1504.csv',
#  '1505.csv',
#  '1506.csv',
#  '1507.csv',
#  '1508.csv',
#  '1509.csv',
#  '151.csv',
#  '1510.csv',
#  '1511.csv',
#  '1512.csv',
#  '1513.csv',
#  '1514.csv',
#  '1515.csv',
#  '1516.csv',
#  '1517.csv',
#  '1518.csv',
#  '1519.csv',
#  '152.csv',
#  '1520.csv',
#  '1521.csv',
#  '1522.csv',
#  '1523.csv',
#  '1524.csv',
#  '1525.csv',
#  '1526.csv',
#  '1527.csv',
#  '1528.csv',
#  '1529.csv',
#  '153.csv',
#  '1530.csv',
#  '1531.csv',
#  '1532.csv',
#  '1533.csv',
#  '1534.csv',
#  '1535.csv',
#  '1536.csv',
#  '1537.csv',
#  '1538.csv',
#  '1539.csv',
#  '154.csv',
#  '1540.csv',
#  '1541.csv',
#  '1542.csv',
#  '1543.csv',
#  '1544.csv',
#  '1545.csv',
#  '1546.csv',
#  '1547.csv',
#  '1548.csv',
#  '1549.csv',
#  '155.csv',
#  '1550.csv',
#  '1551.csv',
#  '1552.csv',
#  '1553.csv',
#  '1554.csv',
#  '1555.csv',
#  '1556.csv',
#  '1557.csv',
#  '1558.csv',
#  '1559.csv',
#  '156.csv',
#  '1560.csv',
#  '1561.csv',
#  '1562.csv',
#  '1563.csv',
#  '1564.csv',
#  '1565.csv',
#  '1566.csv',
#  '1567.csv',
#  '1568.csv',
#  '1569.csv',
#  '157.csv',
#  '1570.csv',
#  '1571.csv',
#  '1572.csv',
#  '1573.csv',
#  '1574.csv',
#  '1575.csv',
#  '1576.csv',
#  '1577.csv',
#  '1578.csv',
#  '1579.csv',
#  '158.csv',
#  '1580.csv',
#  '1581.csv',
#  '1582.csv',
#  '1583.csv',
#  '1584.csv',
#  '1585.csv',
#  '1586.csv',
#  '1587.csv',
#  '1588.csv',
#  '1589.csv',
#  '159.csv',
#  '1590.csv',
#  '1591.csv',
#  '1592.csv',
#  '1593.csv',
#  '1594.csv',
#  '1595.csv',
#  '1596.csv',
#  '1597.csv',
#  '1598.csv',
#  '1599.csv',
#  '16.csv',
#  '160.csv',
#  '1600.csv',
#  '1601.csv',
#  '1602.csv',
#  '1603.csv',
#  '1604.csv',
#  '1605.csv',
#  '1606.csv',
#  '1607.csv',
#  '1608.csv',
#  '1609.csv',
#  '161.csv',
#  '1610.csv',
#  '1611.csv',
#  '1612.csv',
#  '1613.csv',
#  '1614.csv',
#  '1615.csv',
#  '1616.csv',
#  '1617.csv',
#  '1618.csv',
#  '1619.csv',
#  '162.csv',
#  '1620.csv',
#  '1621.csv',
#  '1622.csv',
#  '1623.csv',
#  '1624.csv',
#  '1625.csv',
#  '1626.csv',
#  '1627.csv',
#  '1628.csv',
#  '1629.csv',
#  '163.csv',
#  '1630.csv',
#  '1631.csv',
#  '1632.csv',
#  '1633.csv',
#  '1634.csv',
#  '1635.csv',
#  '1636.csv',
#  '1637.csv',
#  '1638.csv',
#  '1639.csv',
#  '164.csv',
#  '1640.csv',
#  '1641.csv',
#  '1642.csv',
#  '1643.csv',
#  '1644.csv',
#  '1645.csv',
#  '1646.csv',
#  '1647.csv',
#  '1648.csv',
#  '1649.csv',
#  '165.csv',
#  '1650.csv',
#  '1651.csv',
#  '1652.csv',
#  '1653.csv',
#  '1654.csv',
#  '1655.csv',
#  '1656.csv',
#  '1657.csv',
#  '1658.csv',
#  '1659.csv',
#  '166.csv',
#  '1660.csv',
#  '1661.csv',
#  '1662.csv',
#  '1663.csv',
#  '1664.csv',
#  '1665.csv',
#  '1666.csv',
#  '1667.csv',
#  '1668.csv',
#  '1669.csv',
#  '167.csv',
#  '1670.csv',
#  '1671.csv',
#  '1672.csv',
#  '1673.csv',
#  '1674.csv',
#  '1675.csv',
#  '1676.csv',
#  '1677.csv',
#  '1678.csv',
#  '1679.csv',
#  '168.csv',
#  '1680.csv',
#  '1681.csv',
#  '1682.csv',
#  '1683.csv',
#  '1684.csv',
#  '1685.csv',
#  '1686.csv',
#  '1687.csv',
#  '1688.csv',
#  '1689.csv',
#  '169.csv',
#  '1690.csv',
#  '1691.csv',
#  '1692.csv',
#  '1693.csv',
#  '1694.csv',
#  '1695.csv',
#  '1696.csv',
#  '1697.csv',
#  '1698.csv',
#  '1699.csv',
#  '17.csv',
#  '170.csv',
#  '1700.csv',
#  '1701.csv',
#  '1702.csv',
#  '1703.csv',
#  '1704.csv',
#  '1705.csv',
#  '1706.csv',
#  '1707.csv',
#  '1708.csv',
#  '1709.csv',
#  '171.csv',
#  '1710.csv',
#  '1711.csv',
#  '1712.csv',
#  '1713.csv',
#  '1714.csv',
#  '1715.csv',
#  '1716.csv',
#  '1717.csv',
#  '1718.csv',
#  '1719.csv',
#  '172.csv',
#  '1720.csv',
#  '1721.csv',
#  '1722.csv',
#  '1723.csv',
#  '1724.csv',
#  '1725.csv',
#  '1726.csv',
#  '1727.csv',
#  '1728.csv',
#  '1729.csv',
#  '173.csv',
#  '1730.csv',
#  '1731.csv',
#  '1732.csv',
#  '1733.csv',
#  '1734.csv',
#  '1735.csv',
#  '1736.csv',
#  '1737.csv',
#  '1738.csv',
#  '1739.csv',
#  '174.csv',
#  '1740.csv',
#  '1741.csv',
#  '1742.csv',
#  '1743.csv',
#  '1744.csv',
#  '1745.csv',
#  '1746.csv',
#  '1747.csv',
#  '1748.csv',
#  '1749.csv',
#  '175.csv',
#  '1750.csv',
#  '1751.csv',
#  '1752.csv',
#  '1753.csv',
#  '1754.csv',
#  '1755.csv',
#  '1756.csv',
#  '1757.csv',
#  '1758.csv',
#  '1759.csv',
#  '176.csv',
#  '1760.csv',
#  '1761.csv',
#  '1762.csv',
#  '1763.csv',
#  '1764.csv',
#  '1765.csv',
#  '1766.csv',
#  '1767.csv',
#  '1768.csv',
#  '1769.csv',
#  '177.csv',
#  '1770.csv',
#  '1771.csv',
#  '1772.csv',
#  '1773.csv',
#  '1774.csv',
#  '1775.csv',
#  '1776.csv',
#  '1777.csv',
#  '1778.csv',
#  '1779.csv',
#  '178.csv',
#  '1780.csv',
#  '1781.csv',
#  '1782.csv',
#  '1783.csv',
#  '1784.csv',
#  '1785.csv',
#  '1786.csv',
#  '1787.csv',
#  '1788.csv',
#  '1789.csv',
#  '179.csv',
#  '1790.csv',
#  '1791.csv',
#  '1792.csv',
#  '1793.csv',
#  '1794.csv',
#  '1795.csv',
#  '1796.csv',
#  '1797.csv',
#  '1798.csv',
#  '1799.csv',
#  '18.csv',
#  '180.csv',
#  '1800.csv',
#  '1801.csv',
#  '1802.csv',
#  '1803.csv',
#  '1804.csv',
#  '1805.csv',
#  '1806.csv',
#  '1807.csv',
#  '1808.csv',
#  '1809.csv',
#  '181.csv',
#  '1810.csv',
#  '1811.csv',
#  '1812.csv',
#  '1813.csv',
#  '1814.csv',
#  '1815.csv',
#  '1816.csv',
#  '1817.csv',
#  '1818.csv',
#  '1819.csv',
#  '182.csv',
#  '1820.csv',
#  '1821.csv',
#  '1822.csv',
#  '1823.csv',
#  '1824.csv',
#  '1825.csv',
#  '1826.csv',
#  '1827.csv',
#  '1828.csv',
#  '1829.csv',
#  '183.csv',
#  '1830.csv',
#  '1831.csv',
#  '1832.csv',
#  '1833.csv',
#  '1834.csv',
#  '1835.csv',
#  '1836.csv',
#  '1837.csv',
#  '1838.csv',
#  '1839.csv',
#  '184.csv',
#  '1840.csv',
#  '1841.csv',
#  '1842.csv',
#  '1843.csv',
#  '1844.csv',
#  '1845.csv',
#  '1846.csv',
#  '1847.csv',
#  '1848.csv',
#  '1849.csv',
#  '185.csv',
#  '1850.csv',
#  '1851.csv',
#  '1852.csv',
#  '1853.csv',
#  '1854.csv',
#  '1855.csv',
#  '1856.csv',
#  '1857.csv',
#  '1858.csv',
#  '1859.csv',
#  '186.csv',
#  '1860.csv',
#  '1861.csv',
#  '1862.csv',
#  '1863.csv',
#  '1864.csv',
#  '1865.csv',
#  '1866.csv',
#  '1867.csv',
#  '1868.csv',
#  '1869.csv',
#  '187.csv',
#  '1870.csv',
#  '1871.csv',
#  '1872.csv',
#  '1873.csv',
#  '1874.csv',
#  '1875.csv',
#  '1876.csv',
#  '1877.csv',
#  '1878.csv',
#  '1879.csv',
#  '188.csv',
#  '1880.csv',
#  '1881.csv',
#  '1882.csv',
#  '1883.csv',
#  '1884.csv',
#  '1885.csv',
#  '1886.csv',
#  '1887.csv',
#  '1888.csv',
#  '1889.csv',
#  '189.csv',
#  '1890.csv',
#  '1891.csv',
#  '1892.csv',
#  '1893.csv',
#  '1894.csv',
#  '1895.csv',
#  '1896.csv',
#  '1897.csv',
#  '1898.csv',
#  ...]

# %%
X[0]
# Out:
# array([[0.26191445, 0.99499548],
#        [0.23693565, 1.        ],
#        [0.24357557, 0.95316303],
#        [0.25692858, 0.97016047],
#        [0.28369267, 0.97534386],
#        [0.23871246, 0.96380353],
#        [0.25473252, 0.94511292],
#        [0.25899057, 0.92019381],
#        [0.23933963, 0.91030134],
#        [0.2381383 , 0.8854807 ],
#        [0.23789943, 0.89256463],
#        [0.25122058, 0.84208624],
#        [0.21066024, 0.80914789],
#        [0.20316383, 0.81289604],
#        [0.2130221 , 0.83744728],
#        [0.20714779, 0.83129553],
#        [0.21066536, 0.81734178],
#        [0.19381116, 0.80872367],
#        [0.13926251, 0.7611191 ],
#        [0.12030662, 0.76133344],
#        [0.11143062, 0.71412784],
#        [0.09676294, 0.66572501],
#        [0.082709  , 0.64970755],
#        [0.07372706, 0.6229973 ],
#        [0.04580422, 0.59623908],
#        [0.03047691, 0.55207069],
#        [0.05214784, 0.52934263],
#        [0.02552992, 0.49145167],
#        [0.03356855, 0.4589914 ],
#        [0.01993726, 0.39555782],
#        [0.02017592, 0.34239273],
#        [0.        , 0.30487059],
#        [0.0091112 , 0.24329481],
#        [0.02097628, 0.23318604],
#        [0.01887182, 0.21722864],
#        [0.0230786 , 0.21346887],
#        [0.02041735, 0.17823974],
#        [0.02940832, 0.15742829],
#        [0.06113363, 0.14453296],
#        [0.09654328, 0.12172236],
#        [0.1348815 , 0.11147967],
#        [0.149163  , 0.08260865],
#        [0.17270679, 0.0737206 ],
#        [0.22226032, 0.05192747],
#        [0.24635669, 0.0553093 ],
#        [0.28716723, 0.0467342 ],
#        [0.34499127, 0.03154937],
#        [0.37056504, 0.04411023],
#        [0.4152987 , 0.02470982],
#        [0.46659553, 0.0274258 ],
#        [0.49919804, 0.        ],
#        [0.54044487, 0.01104428],
#        [0.60102856, 0.02438739],
#        [0.644591  , 0.00952202],
#        [0.71783666, 0.01644129],
#        [0.74126592, 0.01705817],
#        [0.74526913, 0.00871044],
#        [0.73185504, 0.00519723],
#        [0.74594307, 0.02222166],
#        [0.7674518 , 0.01940471],
#        [0.78509852, 0.04222389],
#        [0.83356367, 0.04115644],
#        [0.86077202, 0.04687667],
#        [0.89529702, 0.04957851],
#        [0.90719118, 0.03974398],
#        [0.92756408, 0.05689772],
#        [0.94670522, 0.09546823],
#        [0.96132463, 0.08707491],
#        [1.        , 0.12954724],
#        [0.97464192, 0.14435258],
#        [0.97709695, 0.16675791],
#        [0.94033765, 0.17026759],
#        [0.93424828, 0.199535  ],
#        [0.89575457, 0.22460216],
#        [0.87594324, 0.20830865],
#        [0.86327441, 0.25140536],
#        [0.84352106, 0.26381269],
#        [0.80735377, 0.25958622],
#        [0.77190215, 0.28919999],
#        [0.72432035, 0.28239995],
#        [0.69695463, 0.31115164],
#        [0.62302296, 0.31438957],
#        [0.59508477, 0.34157188],
#        [0.55376701, 0.36237904],
#        [0.49486303, 0.34306412],
#        [0.45579104, 0.36077791],
#        [0.4082027 , 0.36922017],
#        [0.3650151 , 0.39014791],
#        [0.3603607 , 0.40840822],
#        [0.31600988, 0.41995803],
#        [0.28478207, 0.41742484],
#        [0.24329262, 0.41686655],
#        [0.20283622, 0.43688899],
#        [0.17872606, 0.44105866],
#        [0.15232787, 0.45875553],
#        [0.10865018, 0.44765818],
#        [0.09300845, 0.45769512],
#        [0.0812365 , 0.44255526],
#        [0.06878023, 0.45958178],
#        [0.05165944, 0.45151771]])

# %%
model = load_model('model_1.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
input_data = np.expand_dims(X[0], axis=0)

# %%
input_data
# Out:
# array([[[0.26191445, 0.99499548],
#         [0.23693565, 1.        ],
#         [0.24357557, 0.95316303],
#         [0.25692858, 0.97016047],
#         [0.28369267, 0.97534386],
#         [0.23871246, 0.96380353],
#         [0.25473252, 0.94511292],
#         [0.25899057, 0.92019381],
#         [0.23933963, 0.91030134],
#         [0.2381383 , 0.8854807 ],
#         [0.23789943, 0.89256463],
#         [0.25122058, 0.84208624],
#         [0.21066024, 0.80914789],
#         [0.20316383, 0.81289604],
#         [0.2130221 , 0.83744728],
#         [0.20714779, 0.83129553],
#         [0.21066536, 0.81734178],
#         [0.19381116, 0.80872367],
#         [0.13926251, 0.7611191 ],
#         [0.12030662, 0.76133344],
#         [0.11143062, 0.71412784],
#         [0.09676294, 0.66572501],
#         [0.082709  , 0.64970755],
#         [0.07372706, 0.6229973 ],
#         [0.04580422, 0.59623908],
#         [0.03047691, 0.55207069],
#         [0.05214784, 0.52934263],
#         [0.02552992, 0.49145167],
#         [0.03356855, 0.4589914 ],
#         [0.01993726, 0.39555782],
#         [0.02017592, 0.34239273],
#         [0.        , 0.30487059],
#         [0.0091112 , 0.24329481],
#         [0.02097628, 0.23318604],
#         [0.01887182, 0.21722864],
#         [0.0230786 , 0.21346887],
#         [0.02041735, 0.17823974],
#         [0.02940832, 0.15742829],
#         [0.06113363, 0.14453296],
#         [0.09654328, 0.12172236],
#         [0.1348815 , 0.11147967],
#         [0.149163  , 0.08260865],
#         [0.17270679, 0.0737206 ],
#         [0.22226032, 0.05192747],
#         [0.24635669, 0.0553093 ],
#         [0.28716723, 0.0467342 ],
#         [0.34499127, 0.03154937],
#         [0.37056504, 0.04411023],
#         [0.4152987 , 0.02470982],
#         [0.46659553, 0.0274258 ],
#         [0.49919804, 0.        ],
#         [0.54044487, 0.01104428],
#         [0.60102856, 0.02438739],
#         [0.644591  , 0.00952202],
#         [0.71783666, 0.01644129],
#         [0.74126592, 0.01705817],
#         [0.74526913, 0.00871044],
#         [0.73185504, 0.00519723],
#         [0.74594307, 0.02222166],
#         [0.7674518 , 0.01940471],
#         [0.78509852, 0.04222389],
#         [0.83356367, 0.04115644],
#         [0.86077202, 0.04687667],
#         [0.89529702, 0.04957851],
#         [0.90719118, 0.03974398],
#         [0.92756408, 0.05689772],
#         [0.94670522, 0.09546823],
#         [0.96132463, 0.08707491],
#         [1.        , 0.12954724],
#         [0.97464192, 0.14435258],
#         [0.97709695, 0.16675791],
#         [0.94033765, 0.17026759],
#         [0.93424828, 0.199535  ],
#         [0.89575457, 0.22460216],
#         [0.87594324, 0.20830865],
#         [0.86327441, 0.25140536],
#         [0.84352106, 0.26381269],
#         [0.80735377, 0.25958622],
#         [0.77190215, 0.28919999],
#         [0.72432035, 0.28239995],
#         [0.69695463, 0.31115164],
#         [0.62302296, 0.31438957],
#         [0.59508477, 0.34157188],
#         [0.55376701, 0.36237904],
#         [0.49486303, 0.34306412],
#         [0.45579104, 0.36077791],
#         [0.4082027 , 0.36922017],
#         [0.3650151 , 0.39014791],
#         [0.3603607 , 0.40840822],
#         [0.31600988, 0.41995803],
#         [0.28478207, 0.41742484],
#         [0.24329262, 0.41686655],
#         [0.20283622, 0.43688899],
#         [0.17872606, 0.44105866],
#         [0.15232787, 0.45875553],
#         [0.10865018, 0.44765818],
#         [0.09300845, 0.45769512],
#         [0.0812365 , 0.44255526],
#         [0.06878023, 0.45958178],
#         [0.05165944, 0.45151771]]])

# %%
res = np.argmax(model.predict(input_data))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 17

# %%
one_hot_encoded = np.eye(predictions.shape[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 one_hot_encoded = np.eye(predictions.shape[1])
#
# NameError: name 'predictions' is not defined
